# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('images/23794.jpeg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
from utils import kMeans_cluster

clusteredImg = kMeans_cluster(img)
plt.imshow(clusteredImg)

# %%
from utils import edge_detection

edges = edge_detection(clusteredImg)
plt.imshow(edges, cmap='gray')

# %%
from utils import get_bounding_rect, draw_bounding_box

rect = get_bounding_rect(edges)
img_box = draw_bounding_box(img, rect)
plt.imshow(img_box)

# %%
edges_color = cv2.cvtColor(edges, cv2.COLOR_GRAY2RGB)
edges_box = draw_bounding_box(edges_color, rect)
plt.imshow(edges_box)

# %%
rect
# Out:
# ((869.029541015625, 641.674072265625),
#  (1024.7899169921875, 734.19091796875),
#  88.88080596923828)

# %%
from utils import crop_minAreaRect

edges_crop = crop_minAreaRect(edges, rect)
plt.imshow(edges_crop, cmap='gray')

# %%
foot_rect = get_bounding_rect(edges_crop)
edges_crop = cv2.cvtColor(edges_crop, cv2.COLOR_GRAY2RGB)
foot_box = draw_bounding_box(edges_crop, foot_rect)
plt.imshow(foot_box)

# %%
TRUE_A4_WIDTH = 21
TRUE_A4_LENGTH = 29.7

# %%
a4_width = min(rect[1])
a4_length = max(rect[1])

foot_width = min(foot_rect[1])
foot_length = max(foot_rect[1])

true_foot_width = TRUE_A4_WIDTH * foot_width / a4_width
true_foot_length = TRUE_A4_LENGTH * foot_length / a4_length

# %%
print(true_foot_width)
print(true_foot_length)
# Out:
# 12.892859696213746
# 26.502155560418192
